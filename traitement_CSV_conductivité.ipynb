# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/edureuil/Desktop/Doctorat/data/Manipulation04012022RHO_ARVE/HOBO/20794806.csv")

# %%
df
# Out:
#                                                                                                                                                                                                                                   Titre de tracé : 20794806
# #     Date Heure, GMT-01:00 Plage basse, μS/cm (LGR S/N: 20794806, SEN S/N:... Plage complète, μS/cm (LGR S/N: 20794806, SEN S... Temp., °C (LGR S/N: 20794806, SEN S/N: 20794806) Coupleur détaché (LGR S/N: 20794806)  Fin de fichier (LGR S/N: 20794806)
# 1     01/04/23 11:30:00 AM  0.9                                                0.8                                                15.27                                            Enregistré                                                           NaN
# ...

# %%
nmp=df.to_numpy()
print(nmp) 
print(type(nmp))
# Out:
# [['Fin de fichier (LGR S/N: 20794806)']
#  [nan]
#  [nan]
#  ...
#  [nan]
#  [nan]
#  ['Enregistré']]
# <class 'numpy.ndarray'>
